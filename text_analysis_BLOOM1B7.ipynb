# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/code/data/train/subtask_1/en/')
#os.chdir('/content/drive/My Drive/Colab Notebooks/code/data/test/subtask_1/en/')
#os.chdir('/content/drive/My Drive/Colab Notebooks/code/experiments/')
# Out:
# Mounted at /content/drive

# %%
# %pip install lexicalrichness
# %pip install pandas
# %pip install numpy
# %pip install
# %pip install matplotlib
# %pip install textacy
# %pip install spacy
# %pip install nltk
# %pip install transformers
# Out:
# Collecting lexicalrichness
#   Downloading lexicalrichness-0.5.1.tar.gz (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from lexicalrichness) (1.11.4)
# Requirement already satisfied: textblob>=0.15.3 in /usr/local/lib/python3.10/dist-packages (from lexicalrichness) (0.17.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lexicalrichness) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lexicalrichness) (3.7.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.0.0->lexicalrichness) (1.25.2)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob>=0.15.3->lexicalrichness) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lexicalrichness) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lexicalrichness) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lexicalrichness) (2024.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob>=0.15.3->lexicalrichness) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob>=0.15.3->lexicalrichness) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob>=0.15.3->lexicalrichness) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob>=0.15.3->lexicalrichness) (4.66.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lexicalrichness) (1.16.0)
# Building wheels for collected packages: lexicalrichness
#   Building wheel for lexicalrichness (setup.py) ... done
#   Created wheel for lexicalrichness: filename=lexicalrichness-0.5.1-py3-none-any.whl size=15417 sha256=b705be6cda2c91882269b377052d0c9c78094d3f54462c442f261fa8847923d5
#   Stored in directory: /root/.cache/pip/wheels/cd/ba/80/d4dabc1bf242a672ffc00226a2303a7471bb841c0872b2c212
# Successfully built lexicalrichness
# Installing collected packages: lexicalrichness
# Successfully installed lexicalrichness-0.5.1
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# ERROR: You must give at least one requirement to install (see "pip help install")
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting textacy
#   Downloading textacy-0.13.0-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (5.3.3)
# Requirement already satisfied: catalogue~=2.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (2.0.10)
# Collecting cytoolz>=0.10.1 (from textacy)
#   Downloading cytoolz-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 62.5 MB/s eta 0:00:00
# Collecting floret~=0.10.0 (from textacy)
#   Downloading floret-0.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.4/320.4 kB 40.2 MB/s eta 0:00:00
# Collecting jellyfish>=0.8.0 (from textacy)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.4.2)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from textacy) (3.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.25.2)
# Collecting pyphen>=0.10.0 (from textacy)
#   Downloading pyphen-0.15.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 96.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (2.31.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.2.2)
# Requirement already satisfied: spacy~=3.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (3.7.4)
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.10/dist-packages (from textacy) (4.66.4)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz>=0.10.1->textacy) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->textacy) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (2.4.8)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy~=3.0->textacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (4.11.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy~=3.0->textacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy~=3.0->textacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy~=3.0->textacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy~=3.0->textacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy~=3.0->textacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy~=3.0->textacy) (1.1.1)
# Installing collected packages: pyphen, jellyfish, floret, cytoolz, textacy
# Successfully installed cytoolz-0.12.3 floret-0.10.5 jellyfish-1.0.3 pyphen-0.15.0 textacy-0.13.0
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
import pandas as pd
import numpy as np
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from lexicalrichness import LexicalRichness
import spacy
import textacy
from textacy.text_stats import readability
from matplotlib.mlab import GaussianKDE
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df1 = pd.read_csv("bloom1b7.csv")
df2 = pd.read_csv("human.csv")
df = pd.concat([df1, df2], ignore_index=True)
df=df.drop(df.columns[0], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   prompt  2000 non-null   object
#  1   text    2000 non-null   object
#  2   label   2000 non-null   int64
#  3   model   2000 non-null   object
#  4   domain  2000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 78.2+ KB

# %%
df.head()
# Out:
#                                               prompt  \
# 0  Learn to recognize the warning signs of a migr...
# 1       Open two 15-ounce (425 g) cans of chickpeas.
# 2                            yay it does! I LOOOOOVE
# 3  A healthy BMI has been linked to increased fer...
# 4  to the other person actively so you can respon...
#
#                                                 text  label model  domain
# 0  Learn how you can take preventative steps that...      0     A    wiki
# 1  In a large mixing bowl, combine the water and ...      0     A    wiki
# 2  yay it does! I LOOOOOVE this movie, and my kid...      0     A  tweets
# 3  However, a recent metaanalysis of 13 prospecti...      0     A    wiki
# 4  You need someone who is ready and willing to l...      0     A    wiki

# %%
df['domain'].value_counts()
# Out:
# domain
# tweets    711
# wiki      661
# legal     628
# Name: count, dtype: int64

# %%
df['model'].value_counts()
# Out:
# model
# NO-MODEL    17046
# F            2859
# E            2843
# D            2834
# C            2808
# A            2750
# B            2705
# Name: count, dtype: int64

# %% [markdown]
# ## LexicalRichness metrics

# %%
# Function to calculate lexical richness metrics for each text
def calculate_lexical_metrics(text):
    lex = LexicalRichness(text)
    if lex.words != lex.terms:  # Check if words are not all unique
        window = min(25, lex.words - 1) if lex.words > 1 else 1
        draw = min(lex.words, 42)
        return {
            'Word count': lex.words,
            '(Unique) Word count': lex.terms,
            'Type-token ratio (TTR)': lex.ttr,
            'Root type-token ratio (RTTR)': lex.rttr,
            'Corrected type-token ratio (CTTR)': lex.cttr,
            'Mean segmental type-token ratio (MSTTR)': lex.msttr(segment_window=window),
            'Measure of Textual Lexical Diversity (MTLD)': lex.mtld(threshold=0.72),
            'Hypergeometric distribution diversity (HD-D)': lex.hdd(draws=draw),
            "Herdan's lexical diversity measure": lex.Herdan,
            "Summer's lexical diversity measure": lex.Summer,
            "Dugast's lexical diversity measure": lex.Dugast,
            "Maas's lexical diversity measure": lex.Maas,
            "Yule's K": lex.yulek,
            "Yule's I": lex.yulei,
            "Herdan's Vm": lex.herdanvm,
            "Simpson's D": lex.simpsond
        }
    else:
        # If all words are unique, return None
        return None

lex_metrics_df = df['text'].apply(lambda text: pd.Series(calculate_lexical_metrics(text)))

# Concatenate the original DataFrame
df_with_lex_metrics = pd.concat([df, lex_metrics_df], axis=1)

# %%
lexical_richness_metrics = ['Type-token ratio (TTR)' , 'Root type-token ratio (RTTR)', 'Corrected type-token ratio (CTTR)','Mean segmental type-token ratio (MSTTR)',  'Measure of Textual Lexical Diversity (MTLD)','Hypergeometric distribution diversity (HD-D)', "Herdan's lexical diversity measure", "Summer's lexical diversity measure","Dugast's lexical diversity measure", "Maas's lexical diversity measure",  "Yule's K", "Yule's I","Herdan's Vm",  "Simpson's D" ]

for metric in lexical_richness_metrics:
    plt.figure(figsize=(8,6))
    sns.histplot(data=df_with_lex_metrics, x=metric, hue='label', bins=30, kde=True, multiple='layer', stat='count')
    plt.title(f'Histogram of {metric} by Label')
    plt.show()

# %% [markdown]
# ## Readability metrics

# %%
model_path = "en_core_web_sm"
nlp = spacy.load(model_path)

def get_readability_stats(texts):
    stats_list = []
    for ix, article in enumerate(texts):
        doc = nlp(article)
        stats = {
            'Automated Readability Index': readability.automated_readability_index(doc),
            'Coleman-Liau Index': readability.coleman_liau_index(doc),
            'a': readability.flesch_kincaid_grade_level(doc),
            'Flesch Readability Ease': readability.flesch_reading_ease(doc),
            'Gunning Fog Index': readability.gunning_fog_index(doc),
            'N Characters': len(doc.text),
            'N Unique Words': len(set(token.text.lower() for token in doc if token.is_alpha)),
            'N Words': len(doc),
            'SMOG Index': readability.smog_index(doc)
        }
        stats_list.append(stats)
    return pd.DataFrame(stats_list)

readability_stats = get_readability_stats(df['text'])
df = pd.concat([df.reset_index(drop=True), readability_stats.reset_index(drop=True)], axis=1)

# %%
readability_metrics = ['Automated Readability Index', 'Coleman-Liau Index', 'Flesch-Kincaid Grade Level',
                       'Flesch Readability Ease', 'Gunning Fog Index', 'N Characters',
                       'N Unique Words', 'N Words', 'SMOG Index']
# Plots for each metric
for metric in readability_metrics:
    plt.figure(figsize=(8,6))
    sns.histplot(data=df, x=metric, hue='label', bins=30, kde=True, multiple='layer')
    plt.title(f'Histogram of {metric} by Label')
    plt.show()

# %% [markdown]
# ### Stylistic features

# %%
nlp = spacy.load("en_core_web_sm")

def count_clauses(text):
    doc = nlp(text)
    return sum(1 for token in doc if token.dep_ == 'ROOT')

# Apply spaCy to the entire df
docs = list(nlp.pipe(df['text']))

# Initialize lists to store calculated values
n_tokens_list = []
n_sentences_list = []
n_clauses_list = []
avg_sentence_length_list = []

# Iterate over each document to calculate metrics
for doc in docs:
    n_tokens = len(doc)
    n_sentences = len(list(doc.sents))
    n_clauses = count_clauses(doc.text)
    avg_sentence_length = n_tokens / n_sentences

    # Append calculated values to respective lists
    n_tokens_list.append(n_tokens)
    n_sentences_list.append(n_sentences)
    n_clauses_list.append(n_clauses)
    avg_sentence_length_list.append(avg_sentence_length)

# Add calculated metrics to the dataframe
df['N Tokens'] = n_tokens_list
df['N Sentences'] = n_sentences_list
df['N Clauses'] = n_clauses_list
df['Avg Sentence Length'] = avg_sentence_length_list
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
metrics = ['N Tokens', 'N Sentences', 'N Clauses', 'Avg Sentence Length']

for metric in metrics:
    plt.figure(figsize=(8,6))
    # x='value', hue='category'
    sns.histplot(data=df, x=metric, hue='label', bins=30, kde=True, multiple='layer')
    plt.title(f'Histogram of {metric} by Label')
    plt.show()

# %% [markdown]
# ## Most frequent N-grams
# https://www.kaggle.com/code/harshsingh2209/complete-guide-to-eda-on-text-data

# %%
# Splitting DataFrame based on label
human_df = df[df['label'] == 'human']
generated_df = df[df['label'] == 'generated']

# Function to plot n-gram frequencies
def plot_ngram_frequencies(data, ngram_range=(2, 2), top_n=15, title=''):
    cv = CountVectorizer(ngram_range=ngram_range)
    ngrams = cv.fit_transform(data)
    count_values = ngrams.toarray().sum(axis=0)
    ngram_freq = pd.DataFrame(sorted([(count_values[i], k) for k, i in cv.vocabulary_.items()], reverse=True))
    ngram_freq.columns = ["frequency", "ngram"]
    sns.barplot(x=ngram_freq['frequency'][:top_n], y=ngram_freq['ngram'][:top_n])
    plt.title(title)
    plt.xticks(rotation=45)
    plt.show()

# Bi-grams
plot_ngram_frequencies(human_df['text'], title='Top 15 Most Frequently Occurring Bi-grams (Human)')
plot_ngram_frequencies(generated_df['text'], title='Top 15 Most Frequently Occurring Bi-grams (Generated)')

# Tri-grams
plot_ngram_frequencies(human_df['text'], ngram_range=(3, 3), title='Top 15 Most Frequently Occurring Tri-grams (Human)')
plot_ngram_frequencies(generated_df['text'], ngram_range=(3, 3), title='Top 15 Most Frequently Occurring Tri-grams (Generated)')

# %% [markdown]
# ## Morphological information

# %%
df1 = pd.read_csv("bloom1b7.csv")
df2 = pd.read_csv("human.csv")
df3 = pd.read_csv("bloom3b.csv")
df4 = pd.read_csv("gpt.csv")

df = pd.concat([df1, df2, df3,df4], ignore_index=True)
df=df.drop(df.columns[0], axis=1)

# %%
df['model'].value_counts()
# Out:
# model
# A                1000
# NO-MODEL         1000
# B                1000
# gpt-3.5-turbo    1000
# Name: count, dtype: int64

# %%
nlp = spacy.load("en_core_web_sm")


def extract_morphological_info(text):
    doc = nlp(text)
    morph_info = {
        "text": text,
        "pos_tags": [token.pos_ for token in doc],
        "verb_tenses": [token.tag_ for token in doc if token.pos_ == "VERB"],

    }
    return morph_info

human_morph_info = []
bloom1B_morph_info = []
bloom3B_morph_info = []
gpt_morph_info = []

for index, row in df.iterrows():
    text = row["text"]
    #label = row["label"]
    model = row['model']
    morph_info = extract_morphological_info(text)

    if model == "NO-MODEL":
        human_morph_info.append(morph_info)
    elif model == "A":
        bloom1B_morph_info.append(morph_info)
    elif model == "B":
        bloom3B_morph_info.append(morph_info)
    else:
        gpt_morph_info.append(morph_info)

# Convert the extracted information into dataframes
human_morph_df = pd.DataFrame(human_morph_info)
bloom1B_morph_df = pd.DataFrame(bloom1B_morph_info)
bloom3B_morph_df = pd.DataFrame(bloom3B_morph_info)
gpt_morph_df = pd.DataFrame(gpt_morph_info)

# %%
# Extract POS counts for all classes
human_pos_counts = human_morph_df["pos_tags"].explode().value_counts()
bloom1B_pos_counts = bloom1B_morph_df["pos_tags"].explode().value_counts()
bloom3B_pos_counts = bloom3B_morph_df["pos_tags"].explode().value_counts()
gpt_pos_counts = gpt_morph_df["pos_tags"].explode().value_counts()

# Concatenate the poscounts for all classes
combined_pos_counts = pd.concat([human_pos_counts, bloom1B_pos_counts, bloom3B_pos_counts, gpt_pos_counts], axis=1)
combined_pos_counts.columns = ['Human', 'BLOOM-1b7', 'BLOOM-3b', 'GPT-3.5-Turbo']

# Plot
combined_pos_counts.plot(kind='bar', figsize=(12, 6), color=['orange', 'skyblue', 'darkblue', 'purple'], width=0.6)
plt.title("Distribution of Part-of-Speech Tags")
plt.xlabel("Part-of-Speech Tag")
plt.ylabel("Frequency")
plt.legend()
plt.tight_layout()
plt.show()

# %%
human_pos_counts
# Out:
# pos_tags
# NOUN     9989
# VERB     6725
# ADP      6665
# PUNCT    6402
# DET      5243
# PROPN    4718
# PRON     3974
# AUX      3356
# ADJ      2938
# NUM      2392
# ADV      1805
# CCONJ    1575
# PART     1285
# SCONJ     970
# X         103
# INTJ      101
# SYM        92
# Name: count, dtype: int64

# %%
generated_pos_counts
# Out:
# pos_tags
# NOUN     11879
# VERB      7891
# ADP       7413
# PUNCT     6914
# PRON      5393
# DET       4816
# ADJ       4356
# AUX       3802
# PROPN     3072
# ADV       2463
# SCONJ     1880
# CCONJ     1811
# PART      1617
# NUM       1608
# X          505
# SYM        139
# INTJ       133
# Name: count, dtype: int64

# %%
# Calculate verb tense counts
human_verb_tenses_counts = human_morph_df["verb_tenses"].explode().value_counts()
BLOOM_1b_verb_tenses_counts = bloom1B_morph_df["verb_tenses"].explode().value_counts()
bloom3b_verb_tenses_counts = bloom3B_morph_df["verb_tenses"].explode().value_counts()
gpt_verb_tenses_counts = gpt_morph_df["verb_tenses"].explode().value_counts()

# Concatenate the verb tense counts for human and generated texts
combined_verb_tenses_counts = pd.concat([human_verb_tenses_counts, BLOOM_1b_verb_tenses_counts, bloom3b_verb_tenses_counts, gpt_verb_tenses_counts], axis=1)
combined_verb_tenses_counts.columns = ['Human', 'BLOOM-1b', 'BLOOM-3b', 'GPT-3.5-Turbo']

# Plot
combined_verb_tenses_counts.plot(kind='bar', figsize=(12, 6), color=['orange', 'skyblue', 'darkblue', 'purple'])

plt.title('Distribution of Verb Tenses in Human and Generated Texts')
plt.xlabel('Verb Tense')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
plt.show()
